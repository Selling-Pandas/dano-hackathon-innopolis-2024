# %%
import pandas as pd
# Out:
# /var/folders/vc/rj9dgp2156q5rmfbj17spkvh0000gn/T/ipykernel_8996/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_spss('../full_dataset_2017.sav')
df
# Out:
#          idind  vredid_i        vid_i      vid_h        uid_i      uid_h  \
# 0          3.0   34201.0    1001201.0    10012.0    1001201.0    10012.0
# 1          7.0   34401.0    1000301.0    10003.0    1000301.0    10003.0
# 2          9.0   34001.0    1000401.0    10004.0    1000401.0    10004.0
# 3         37.0   41902.0    1002402.0    10024.0    1002402.0    10024.0
# 4         60.0   27302.0    1004702.0    10047.0    1004702.0    10047.0
# ...        ...       ...          ...        ...          ...        ...
# 12436  57089.0   32106.0    1015106.0    10151.0          NaN        NaN
# 12437  57090.0   40506.0    1012506.0    10125.0          NaN        NaN
# 12438  57092.0   38312.0    1011412.0    10114.0          NaN        NaN
# 12439  57093.0   29205.0    1005906.0    10059.0          NaN        NaN
# 12440  58397.0  559106.0  136098906.0  1360989.0  136098906.0  1360989.0
#
#              tid_i      tid_h      sid_i    sid_h  ...  vm98  vm99  vm100  \
# ...

# %%
df['vj161.3y'].dropna().hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['vj161.3y'].dropna().hist()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_core.py:129, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      62 """
#      63 Draw histogram of the input series using matplotlib.
#      64
#    (...)
#     126     >>> hist = ser.groupby(level=0).hist()
#     127 """
#     128 plot_backend = _get_plot_backend(backend)
# --> 129 return plot_backend.hist_series(
#     130     self,
#     131     by=by,
#     132     ax=ax,
#     133     grid=grid,
#     134     xlabelsize=xlabelsize,
#     135     xrot=xrot,
#     136     ylabelsize=ylabelsize,
#     137     yrot=yrot,
#     138     figsize=figsize,
#     139     bins=bins,
# ...

# %%
df[df['idind'] == ]
