# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import scipy
import json

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 14, 8
plt.rcParams['font.size'] = 18
plt.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')
import matplotlib.font_manager as font_manager
font_dir = [r"C:\Users\legrey4ik\OneDrive\Рабочий стол\hse sans"]
for font in font_manager.findSystemFonts(font_dir):
    font_manager.fontManager.addfont(font)
plt.rcParams['font.family'] = 'hse sans'

# %%
df = pd.read_csv('df_extended_v2_remote.csv')

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  idind        region     city_type  age  \
# 0                0           0     37   Волосовский           ПГТ   59
# 1                1           1    122   Волосовский          Село   40
# 2                2           2    125   Волосовский          Село   53
# 3                3           3    126   Волосовский          Село   47
# 4                4           4    132   Волосовский          Село   54
# ...            ...         ...    ...           ...           ...  ...
# 3864          3864        3864  56979  Московская о          Село   34
# 3865          3865        3865  56982  Московская о          Село   39
# 3866          3866        3866  56986  Московская о          Село   32
# 3867          3867        3867  57005     г. Москва  Областной це   19
# 3868          3868        3868  57007     г. Москва  Областной це   57
#
#       is_male      industry   log_wage  is_gov  ...  vj72.5h3  vj72.5h2  \
# ...

# %%
with open("deleted_salary.json") as deld:
    deld = pd.Series(json.load(deld))

# %%
clear_df = df[deld.tolist()]

# %%
clear_df
# Out:
#       Unnamed: 0.1  Unnamed: 0  idind        region     city_type  age  \
# 0                0           0     37   Волосовский           ПГТ   59
# 1                1           1    122   Волосовский          Село   40
# 2                2           2    125   Волосовский          Село   53
# 3                3           3    126   Волосовский          Село   47
# 4                4           4    132   Волосовский          Село   54
# ...            ...         ...    ...           ...           ...  ...
# 3861          3861        3861  56966  г. Санкт-Пет  Областной це   33
# 3862          3862        3862  56970  г. Санкт-Пет  Областной це   32
# 3863          3863        3863  56976  Московская о          Село   37
# 3864          3864        3864  56979  Московская о          Село   34
# 3868          3868        3868  57007     г. Москва  Областной це   57
#
#       is_male      industry   log_wage  is_gov  ...  vj72.5h3  vj72.5h2  \
# ...

# %%
clear_df['log_wage'].describe()
# Out:
# count    3679.000000
# mean        9.815624
# std         0.549982
# min         8.549514
# 25%         9.465806
# 50%         9.802278
# 75%        10.158950
# max        11.020430
# Name: log_wage, dtype: float64
