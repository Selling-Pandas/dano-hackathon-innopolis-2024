# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import scipy
from spandas import preprocessing as pr
from spandas import plots as pt

# %%
# %pip install pyreadstat

# %%
df = pd.read_csv("df_extended_v2.csv")
df
# Out:
#       Unnamed: 0  idind        region     city_type  age  is_male  \
# 0              0     37   Волосовский           ПГТ   59        1
# 1              1    122   Волосовский          Село   40        0
# 2              2    125   Волосовский          Село   53        0
# 3              3    126   Волосовский          Село   47        1
# 4              4    132   Волосовский          Село   54        0
# ...          ...    ...           ...           ...  ...      ...
# 3864        3864  56979  Московская о          Село   34        0
# 3865        3865  56982  Московская о          Село   39        1
# 3866        3866  56986  Московская о          Село   32        1
# 3867        3867  57005     г. Москва  Областной це   19        1
# 3868        3868  57007     г. Москва  Областной це   57        0
#
#           industry   log_wage  is_gov  internet  ...  vj72.5h4  vj72.5h3  \
# 0     НАУКА, КУЛЬТ   8.954980       0         1  ...       NaN       NaN
# ...

# %%
full_df = pd.read_spss("full_dataset_2017.sav")
full_df
# Out:
#          idind  vredid_i        vid_i      vid_h        uid_i      uid_h  \
# 0          3.0   34201.0    1001201.0    10012.0    1001201.0    10012.0
# 1          7.0   34401.0    1000301.0    10003.0    1000301.0    10003.0
# 2          9.0   34001.0    1000401.0    10004.0    1000401.0    10004.0
# 3         37.0   41902.0    1002402.0    10024.0    1002402.0    10024.0
# 4         60.0   27302.0    1004702.0    10047.0    1004702.0    10047.0
# ...        ...       ...          ...        ...          ...        ...
# 12436  57089.0   32106.0    1015106.0    10151.0          NaN        NaN
# 12437  57090.0   40506.0    1012506.0    10125.0          NaN        NaN
# 12438  57092.0   38312.0    1011412.0    10114.0          NaN        NaN
# 12439  57093.0   29205.0    1005906.0    10059.0          NaN        NaN
# 12440  58397.0  559106.0  136098906.0  1360989.0  136098906.0  1360989.0
#
#              tid_i      tid_h      sid_i    sid_h  ...  vm98  vm99  vm100  \
# ...

# %%
full_df['v_educ']
# Out:
# 0        10 и более классов школы и какое-либо професс....
# 1                                          7 классов школы
# 2                                      техникум с дипломом
# 3        среднее образование - есть аттестат о ср. обра...
# 4        10 и более классов школы и какое-либо професс....
#                                ...
# 12436                                      8 классов школы
# 12437                                                  NaN
# 12438                                                  NaN
# 12439                                                  NaN
# 12440                                                  NaN
# Name: v_educ, Length: 12441, dtype: category
# Categories (26, object): ['0 классов школы', '1 класс школы', '1-2 года в высшем учебном заведении', '10 и более классов школы без аттестата о сред..., ..., 'аспирантура и т.п. с дипломом', 'есть диплом о высшем образовании', 'среднее образование - есть аттестат о ср. обр..., 'техникум с дипломом']

# %%
for id in df['idind']:
    print(full_df[full_df['idind'] == id]['v_educ'].values)
# Out:
# ['среднее образование - есть аттестат о ср. обр...]
# Categories (26, object): ['0 классов школы', '1 класс школы', '1-2 года в высшем учебном заведении', '10 и более классов школы без аттестата о сред..., ..., 'аспирантура и т.п. с дипломом', 'есть диплом о высшем образовании', 'среднее образование - есть аттестат о ср. обр..., 'техникум с дипломом']
# ['есть диплом о высшем образовании']
# Categories (26, object): ['0 классов школы', '1 класс школы', '1-2 года в высшем учебном заведении', '10 и более классов школы без аттестата о сред..., ..., 'аспирантура и т.п. с дипломом', 'есть диплом о высшем образовании', 'среднее образование - есть аттестат о ср. обр..., 'техникум с дипломом']
# ['среднее образование - есть аттестат о ср. обр...]
# ...
